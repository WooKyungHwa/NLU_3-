# %% [markdown]
# <a href="https://colab.research.google.com/github/ttogle918/NLU_3-/blob/main/NLU_STS_3_%EA%B9%80%EC%97%B0%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen_Shot_2022-05-12_at_8.04.40_PM.png](data:image/png;base64,...)
